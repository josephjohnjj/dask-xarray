# %% [markdown]
# # Xarray with Dask
# This tutorial demonstrates how we can use Xarrays with Dask.
#
# Learning outcomes of the tutorial are:
# 1. Learn how to use Xarrays with Dask.
# 2. Learn how to scale Xarray on Dask
#
# Prerequisite:
# 1. Experience with Dask High-level objects

# %% [markdown]
# ![](figs/xarray.png)
# Xarray extends the labeled data functionality of Pandas to N-dimensional array-like datasets. It shares a similar API to NumPy and Pandas and supports both Dask and NumPy arrays under the hood.

# %% [markdown]
# ## Xarray basic

# %%
import numpy as np
import pandas as pd
import xarray as xr

# %% [markdown]
# In Xarray a labeled, N-dimensional array is called
# <span style="color:deepskyblue"> **DataArray**</span>. <span style="color:deepskyblue"> **Dimensions**</span>  provide names that xarray uses instead of the axis argument found in many numpy functions.  <span style="color:deepskyblue"> **Coordinates**</span> enable fast label based indexing and alignment, similar functionality of the index found on a pandas DataFrame.

# %%
data = xr.DataArray(np.random.randn(2, 3), dims=("x", "y"), coords={"x": [10, 20]})
data
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[-0.83916812,  1.58833431, -1.10314839],
#        [-1.67024216,  0.62706904, -0.67416074]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y

# %%
data.dims
# Out:
# ('x', 'y')

# %%
data.coords
# Out:
# Coordinates:
#   * x        (x) int64 10 20

# %% [markdown]
# ### Indexing in Xarray

# %% [markdown]
# Positional and by integer label, like numpy

# %%
data[0, :]
# Out:
# <xarray.DataArray (y: 3)>
# array([-0.83916812,  1.58833431, -1.10314839])
# Coordinates:
#     x        int64 10
# Dimensions without coordinates: y

# %% [markdown]
# loc or "location": positional and coordinate label, like pandas

# %%
data.loc[10]
# Out:
# <xarray.DataArray (y: 3)>
# array([-0.83916812,  1.58833431, -1.10314839])
# Coordinates:
#     x        int64 10
# Dimensions without coordinates: y

# %% [markdown]
# isel or "integer select":  by dimension name and integer label

# %%
data.isel(x=0)
# Out:
# <xarray.DataArray (y: 3)>
# array([-0.83916812,  1.58833431, -1.10314839])
# Coordinates:
#     x        int64 10
# Dimensions without coordinates: y

# %% [markdown]
# sel or "select": by dimension name and coordinate label

# %%
data.sel(x=10)
# Out:
# <xarray.DataArray (y: 3)>
# array([-0.83916812,  1.58833431, -1.10314839])
# Coordinates:
#     x        int64 10
# Dimensions without coordinates: y

# %% [markdown]
# Label-based indexing is particularly usesful as we dont need to know how our array is organized. All we need to know are the dimension name and the label we wish to index. **data.sel(x=10)**,  works regardless of whether x is the first or second dimension of the array and regardless of whether 10 is the first or second element of x.

# %% [markdown]
# Xarray works similar to Numpy arrays with the additional option of using labels.

# %%
mean = data.mean(dim="x")
mean
# Out:
# <xarray.DataArray (y: 3)>
# array([-1.25470514,  1.10770167, -0.88865456])
# Dimensions without coordinates: y

# %%
a = xr.DataArray(np.random.randn(3), [data.coords["y"]])
a
# Out:
# <xarray.DataArray (y: 3)>
# array([ 0.42847105,  1.59769192, -0.18039149])
# Coordinates:
#   * y        (y) int64 0 1 2

# %%
b = xr.DataArray(np.random.randn(4), dims="z")
b
# Out:
# <xarray.DataArray (z: 4)>
# array([ 1.47058485, -0.95211679,  0.48752764, -0.12317962])
# Dimensions without coordinates: z

# %% [markdown]
# Another advantage of Xarray is that arithmetic operations broadcast is possible for DataArray of different dimension.

# %%
a + b
# Out:
# <xarray.DataArray (y: 3, z: 4)>
# array([[ 1.8990559 , -0.52364574,  0.91599868,  0.30529143],
#        [ 3.06827678,  0.64557513,  2.08521956,  1.4745123 ],
#        [ 1.29019336, -1.13250828,  0.30713615, -0.30357111]])
# Coordinates:
#   * y        (y) int64 0 1 2
# Dimensions without coordinates: z

# %%
data
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[-0.83916812,  1.58833431, -1.10314839],
#        [-1.67024216,  0.62706904, -0.67416074]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y
# Attributes:
#     long_name:         random velocity
#     units:             metres/sec
#     description:       A random variable created as an example.
#     random_attribute:  123

# %%
data.T
# Out:
# <xarray.DataArray (y: 3, x: 2)>
# array([[-0.83916812, -1.67024216],
#        [ 1.58833431,  0.62706904],
#        [-1.10314839, -0.67416074]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y
# Attributes:
#     long_name:         random velocity
#     units:             metres/sec
#     description:       A random variable created as an example.
#     random_attribute:  123

# %%
data - data.T
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[0., 0., 0.],
#        [0., 0., 0.]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y

# %% [markdown]
# Xarray also supports groupby operations similar to the pandas API.

# %%
labels = xr.DataArray(["E", "F", "E"], [data.coords["y"]], name="labels")
labels
# Out:
# <xarray.DataArray 'labels' (y: 3)>
# array(['E', 'F', 'E'], dtype='<U1')
# Coordinates:
#   * y        (y) int64 0 1 2

# %%
data.groupby(labels).mean("y")
# Out:
# <xarray.DataArray (x: 2, labels: 2)>
# array([[-0.97115825,  1.58833431],
#        [-1.17220145,  0.62706904]])
# Coordinates:
#   * x        (x) int64 10 20
#   * labels   (labels) object 'E' 'F'
# Attributes:
#     long_name:         random velocity
#     units:             metres/sec
#     description:       A random variable created as an example.
#     random_attribute:  123

# %%
data.groupby(labels).map(lambda x: x - x.min())
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[0.83107404, 0.96126527, 0.56709377],
#        [0.        , 0.        , 0.99608142]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y

# %% [markdown]
# In Xarray we can also set metadata attributes. <span style="color:deepskyblue"> **attrs**</span> is just a Python dictionary, so you can assign anything you wish.

# %%
data.attrs["long_name"] = "random velocity"
data.attrs["units"] = "metres/sec"
data.attrs["description"] = "A random variable created as an example."
data.attrs["random_attribute"] = 123

data.attrs
# Out:
# {'long_name': 'random velocity',
#  'units': 'metres/sec',
#  'description': 'A random variable created as an example.',
#  'random_attribute': 123}

# %% [markdown]
# The metadata provide can be used to plot the data

# %%
data.plot()

# %% [markdown]
# Xarray objects can be easily converted to and from pandas objects

# %%
series = data.to_series()
series
# Out:
# x   y
# 10  0   -0.839168
#     1    1.588334
#     2   -1.103148
# 20  0   -1.670242
#     1    0.627069
#     2   -0.674161
# dtype: float64

# %%
reverse = series.to_xarray()
reverse
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[-0.83916812,  1.58833431, -1.10314839],
#        [-1.67024216,  0.62706904, -0.67416074]])
# Coordinates:
#   * x        (x) int64 10 20
#   * y        (y) int64 0 1 2
